# %%
import mysql.connector

def test_mysql_connection(config):
    try:
        # Attempt to establish a connection to the MySQL server
        connection = mysql.connector.connect(**config)
        
        # If connection is successful, print a success message
        if connection.is_connected():
            print("Connection to MySQL server successful")
            # Close the connection
            connection.close()
    except mysql.connector.Error as err:
        # If connection fails, print the error message
        print(f"Error: {err}")

# Configuration dictionary
config = {
    'user': 'jmc',
    'password': 'jmc',
    'host': '10.18.16.100',
    'port': '3307',
    'database': 'Fast_Freeway_Sensor_Data_XIE'
}

# Call the function to test the connection
test_mysql_connection(config)
# Out:
# Error: 2003: Can't connect to MySQL server on '10.18.16.100:3307' (10060 A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond)

# %%
# Sensor records separating function

import csv
import os
import mysql
import mysql.connector

def connect_to_mysql():
    # MySQL connection parameters
    config = {
        'user': 'jmc',
        'password': 'jmc',
        'host': '10.18.16.100',
        'port': "3306",
        'database': 'Fast_Freeway_Sensor_Data_XIE'
    }

    # Establishing MySQL connection
    connection = mysql.connector.connect(**config)
    return connection

def fetch_data_and_create_csv(connection, chunk_size=1000):
    cursor = connection.cursor()

    # Selecting data from the table
    query = "SELECT * FROM `2018`"
    cursor.execute(query)

    while True:
        # Fetching rows in chunks
        rows = cursor.fetchmany(chunk_size)

        if not rows:
            break  # No more rows to fetch

        # Creating a folder to store CSV files
        folder_path = "C:/Users/Tarek Zahid/Desktop/xie/sensor_files_separated/2018"
        os.makedirs(folder_path, exist_ok=True)

        # Process data and create CSV files
        for row in rows:
            detector_id = row[22]  
            csv_file_path = os.path.join(folder_path, f"{detector_id}.csv")

            # Appending data to CSV file
            with open(csv_file_path, mode='a', newline='') as csv_file:
                csv_writer = csv.writer(csv_file)
                csv_writer.writerow(row)

    cursor.close()

# %%
connection = connect_to_mysql()
fetch_data_and_create_csv(connection)
connection.close()

# %%
# add header to files

import os
import pandas as pd

def add_header_to_csv_files(folder_path, header):
    # Get a list of CSV files in the folder
    csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

    # Iterate through each CSV file
    for csv_file in csv_files:
        file_path = os.path.join(folder_path, csv_file)

        # Read the CSV file
        df = pd.read_csv(file_path, header=None)

        # Add the header to the DataFrame
        df.columns = header

        # Save the DataFrame back to the CSV file
        df.to_csv(file_path, index=False)

        print(f"Header added to: {csv_file}")

# Example usage:
folder_path = 'C:/Users/Tarek Zahid/Desktop/xie/sensor_files_separated/1. raw individual sensor files/2018'
header = ['DateTimeStamp', 'Path', 'RoadIndex', 'RoadwayID', 'SegmentID', 'Lane', 'DeviceID',
          'Volume', 'Volume1', 'Volume2', 'Volume3', 'Volume4', 'Volume5', 'Volume6', 'Occupancy',
          'Speed', 'Poll_Count', 'Failure', 'RoadType', 'Location', 'Polling_Period', 'Invalid',
          'DetectorID', 'DayOfWeek', 'DateValue', 'HourIdx', 'Holiday']

add_header_to_csv_files(folder_path, header)

# %% [markdown]
# Get common csv files in 2018 and 2019

# %%
import os
import shutil

def get_common_csv_files(folder1, folder2):
    files_folder1 = set(file for file in os.listdir(folder1) if file.endswith('.csv'))
    files_folder2 = set(file for file in os.listdir(folder2) if file.endswith('.csv'))
    
    common_files = files_folder1.intersection(files_folder2)
    return common_files

def copy_files(source_folder, destination_folder, files_to_copy):
    for file in files_to_copy:
        source_path = os.path.join(source_folder, file)
        destination_path = os.path.join(destination_folder, file)
        shutil.copy2(source_path, destination_path)

# Replace these paths with your actual paths
folder1_path = 'D:/xie_sepa/2018'
folder2_path = 'D:/xie_sepa/2019'
destination_folder1_path = 'D:/xie_sepa/common/2018'
destination_folder2_path = 'D:/xie_sepa/common/2019'

common_files = get_common_csv_files(folder1_path, folder2_path)

# Copy common files to destination folders
copy_files(folder1_path, destination_folder1_path, common_files)
copy_files(folder2_path, destination_folder2_path, common_files)

print("Common CSV files copied successfully.")
# Out:
# Common CSV files copied successfully.

# %% [markdown]
# 2. get the transformed - aggregated dataset from the raw sensor files:

# %%
import os
import pandas as pd

def process_csv(source_folder, destination_folder):
    # Create destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Get a list of CSV files in the source folder
    csv_files = [file for file in os.listdir(source_folder) if file.endswith('.csv')]

    print(f"Total CSV files found: {len(csv_files)}")

    # Initialize count for files saved
    files_saved_count = 0

    # Iterate through each CSV file
    for idx, csv_file in enumerate(csv_files):
        file_path = os.path.join(source_folder, csv_file)
        destination_path = os.path.join(destination_folder, csv_file)

        # Read CSV file
        df = pd.read_csv(file_path)

        # Check if 'Lane' column contains only 1
        if 'Lane' in df.columns and (df['Lane'] == 1).all():
            # Save the file with specified columns
            df[['DateTimeStamp', 'Occupancy', 'Volume', 'Speed']].to_csv(destination_path, index=False)
            print(f"Saved: {csv_file} - Lane column has only value 1, only specified columns saved.")
            files_saved_count += 1
        else:
            # Check if DataFrame has more than one record for each DateTimeStamp
            multiple_records_mask = df['DateTimeStamp'].duplicated(keep=False)
            df_to_process = df[multiple_records_mask]

            if not df_to_process.empty:
                # Group by DateTimeStamp, calculate aggregates
                grouped_df = df_to_process.groupby(['DateTimeStamp']).agg({
                    'Volume': 'sum',
                    'Occupancy': 'sum',
                    'Speed': 'mean'
                }).reset_index()

                # Save the grouped data to a new CSV file
                grouped_df.to_csv(destination_path, columns=['DateTimeStamp', 'Occupancy', 'Volume', 'Speed'], index=False)

                # Increment count for files saved
                files_saved_count += 1

                # Display progress
                progress_percentage = (idx + 1) / len(csv_files) * 100
                print(f"Processed: {progress_percentage:.2f}% - {csv_file}")

    # Print the number of files saved at the destination folder
    print(f"Total files saved at destination folder: {files_saved_count}")

# Example usage:
source_folder = 'E:/xie/Sensor Files/1. raw data - separated sensor files - num checked out with the db/2019'
destination_folder = 'E:/xie/Sensor Files/2. transformed - aggregated sensor files/2019'
process_csv(source_folder, destination_folder)

# %%
import os
import pandas as pd

def process_csv(source_folder, destination_folder):
    # Create destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Get a list of CSV files in the source folder
    csv_files = [file for file in os.listdir(source_folder) if file.endswith('.csv')]

    print(f"Total CSV files found: {len(csv_files)}")

    # Initialize count for files saved
    files_saved_count = 0

    # Iterate through each CSV file
    for idx, csv_file in enumerate(csv_files):
        file_path = os.path.join(source_folder, csv_file)
        destination_path = os.path.join(destination_folder, csv_file)

        # Read CSV file
        df = pd.read_csv(file_path)

        # Check if 'Lane' column contains only one unique value
        if 'Lane' in df.columns and df['Lane'].nunique() == 1:
            # Check if the unique value is 1, 2, 3, or 4
            unique_value = df['Lane'].unique()[0]
            if unique_value in [1, 2, 3, 4]:
                # Save the file with specified columns
                df[['DateTimeStamp', 'Occupancy', 'Volume', 'Speed']].to_csv(destination_path, index=False)
                print(f"Saved: {csv_file} - Lane column has only value {unique_value}, only specified columns saved.")
                files_saved_count += 1
                continue

        # Proceed with the aggregation process

        # Check if DataFrame has more than one record for each DateTimeStamp
        multiple_records_mask = df['DateTimeStamp'].duplicated(keep=False)
        df_to_process = df[multiple_records_mask]

        if not df_to_process.empty:
            # Group by DateTimeStamp, calculate aggregates
            grouped_df = df_to_process.groupby(['DateTimeStamp']).agg({
                'Volume': 'sum',
                'Occupancy': 'sum',
                'Speed': 'mean'
            }).reset_index()

            # Save the grouped data to a new CSV file
            grouped_df.to_csv(destination_path, columns=['DateTimeStamp', 'Occupancy', 'Volume', 'Speed'], index=False)

            # Increment count for files saved
            files_saved_count += 1

            # Display progress
            progress_percentage = (idx + 1) / len(csv_files) * 100
            print(f"Processed: {progress_percentage:.2f}% - {csv_file}")

    # Print the number of files saved at the destination folder
    print(f"Total files saved at destination folder: {files_saved_count}")

# Example usage:
source_folder = 'E:/xie/Sensor Files/1. raw data - separated sensor files - num checked out with the db/2019'
destination_folder = 'E:/xie/Sensor Files/2. transformed - aggregated sensor files/2019'
process_csv(source_folder, destination_folder)
# Out:
# Total CSV files found: 868
# Saved: 1.555.738.csv - Lane column has only value 3, only specified columns saved.
# Saved: 1.556.735.csv - Lane column has only value 3, only specified columns saved.
# Processed: 0.35% - 10.1.267.csv
# Processed: 0.46% - 10.2.268.csv
# Processed: 0.58% - 101.1.35.csv
# Processed: 0.69% - 101.1.755.csv
# Processed: 0.81% - 102.1.769.csv
# Processed: 0.92% - 102.2.37.csv
# Processed: 1.04% - 102.2.771.csv
# Processed: 1.15% - 102.3.37.csv
# Processed: 1.27% - 103.1.770.csv
# Processed: 1.38% - 103.2.40.csv
# Processed: 1.50% - 109.1.37.csv
# Processed: 1.61% - 109.2.772.csv
# Processed: 1.73% - 110.1.41.csv
# Processed: 1.84% - 110.1.756.csv
# Processed: 1.96% - 110.2.41.csv
# Processed: 2.07% - 111.1.42.csv
# Processed: 2.19% - 112.2.44.csv
# Processed: 2.30% - 113.2.45.csv
# Processed: 2.42% - 114.2.757.csv
# Saved: 115.1.45.csv - Lane column has only value 1, only specified columns saved.
# Saved: 116.2.45.csv - Lane column has only value 1, only specified columns saved.
# Processed: 2.76% - 117.1.46.csv
# Processed: 2.88% - 117.2.766.csv
# Processed: 3.00% - 117.3.767.csv
# Processed: 3.11% - 118.2.763.csv
# Processed: 3.23% - 121.1.765.csv
# Processed: 3.34% - 121.2.43.csv
# Processed: 3.46% - 121.3.768.csv
# Processed: 3.57% - 122.1.758.csv
# Processed: 3.69% - 122.2.48.csv
# Processed: 3.80% - 123.2.50.csv
# Processed: 3.92% - 124.2.49.csv
# Processed: 4.03% - 125.2.49.csv
# Saved: 126.1.49.csv - Lane column has only value 1, only specified columns saved.
# Saved: 126.1.759.csv - Lane column has only value 1, only specified columns saved.
# Processed: 4.38% - 127.1.531.csv
# Processed: 4.49% - 127.1.759.csv
# Processed: 4.61% - 127.2.531.csv
# Processed: 4.72% - 129.1.760.csv
# Saved: 129.2.49.csv - Lane column has only value 2, only specified columns saved.
# Processed: 4.95% - 129.2.751.csv
# Processed: 5.07% - 132.1.80.csv
# Saved: 134.1.80.csv - Lane column has only value 1, only specified columns saved.
# Saved: 135.1.80.csv - Lane column has only value 1, only specified columns saved.
# Processed: 5.41% - 136.1.47.csv
# Processed: 5.53% - 136.2.47.csv
# Processed: 5.65% - 136.2.762.csv
# Processed: 5.76% - 138.1.53.csv
# Processed: 5.88% - 138.2.55.csv
# Saved: 139.2.53.csv - Lane column has only value 1, only specified columns saved.
# Processed: 6.11% - 141.2.55.csv
# Processed: 6.22% - 142.1.55.csv
# Processed: 6.34% - 142.2.54.csv
# Processed: 6.45% - 144.1.54.csv
# Processed: 6.57% - 146.2.238.csv
# Processed: 6.68% - 148.2.58.csv
# Processed: 6.80% - 149.2.240.csv
# Saved: 15.1.6.csv - Lane column has only value 1, only specified columns saved.
# Saved: 15.2.6.csv - Lane column has only value 1, only specified columns saved.
# Processed: 7.14% - 150.2.58.csv
# Processed: 7.26% - 154.2.240.csv
# Processed: 7.37% - 155.1.240.csv
# Processed: 7.49% - 155.2.239.csv
# Processed: 7.60% - 156.2.57.csv
# Saved: 157.1.240.csv - Lane column has only value 1, only specified columns saved.
# Processed: 7.83% - 159.2.57.csv
# Processed: 7.95% - 160.2.242.csv
# Processed: 8.06% - 161.1.242.csv
# Processed: 8.18% - 162.1.197.csv
# Processed: 8.29% - 162.2.197.csv
# Processed: 8.41% - 163.1.72.csv
# Processed: 8.53% - 166.1.210.csv
# Processed: 8.64% - 167.1.531.csv
# Processed: 8.76% - 167.1.753.csv
# Processed: 8.87% - 167.2.210.csv
# Processed: 8.99% - 167.2.754.csv
# Processed: 9.10% - 168.1.196.csv
# Processed: 9.22% - 168.2.196.csv
# Processed: 9.33% - 168.2.532.csv
# Processed: 9.45% - 169.3.210.csv
# Processed: 9.56% - 17.2.141.csv
# Processed: 9.68% - 170.2.761.csv
# Processed: 9.79% - 171.1.196.csv
# Processed: 9.91% - 171.1.761.csv
# Processed: 10.02% - 171.2.47.csv
# Processed: 10.14% - 171.2.764.csv
# Processed: 10.25% - 171.3.541.csv
# Saved: 171.3.761.csv - Lane column has only value 1, only specified columns saved.
# Processed: 10.48% - 171.4.763.csv
# Processed: 10.60% - 172.1.51.csv
# Saved: 174.1.752.csv - Lane column has only value 1, only specified columns saved.
# Saved: 175.1.51.csv - Lane column has only value 1, only specified columns saved.
# Processed: 10.94% - 179.2.75.csv
# Processed: 11.06% - 180.2.75.csv
# Processed: 11.18% - 180.3.51.csv
# Processed: 11.29% - 181.1.80.csv
# Saved: 182.1.75.csv - Lane column has only value 1, only specified columns saved.
# Saved: 184.1.80.csv - Lane column has only value 1, only specified columns saved.
# Processed: 11.64% - 190.1.74.csv
# Processed: 11.75% - 190.1.750.csv
# Processed: 11.87% - 190.2.74.csv
# Processed: 11.98% - 190.3.74.csv
# Processed: 12.10% - 192.2.74.csv
# Processed: 12.21% - 194.1.71.csv
# Saved: 195.1.71.csv - Lane column has only value 1, only specified columns saved.
# Processed: 12.44% - 196.2.69.csv
# Processed: 12.56% - 197.2.69.csv
# Processed: 12.67% - 198.1.70.csv
# Saved: 199.1.70.csv - Lane column has only value 1, only specified columns saved.
# Processed: 12.90% - 2.1.268.csv
# Processed: 13.02% - 2.2.267.csv
# Saved: 2.749.727.csv - Lane column has only value 3, only specified columns saved.
# Processed: 13.25% - 200.1.39.csv
# Saved: 201.1.39.csv - Lane column has only value 1, only specified columns saved.
# Processed: 13.48% - 202.1.69.csv
# Processed: 13.59% - 202.2.68.csv
# Processed: 13.71% - 202.3.67.csv
# Processed: 13.82% - 202.4.66.csv
# Processed: 13.94% - 203.1.65.csv
# Processed: 14.06% - 203.2.67.csv
# Processed: 14.17% - 203.3.68.csv
# Processed: 14.29% - 203.4.69.csv
# Processed: 14.40% - 204.1.64.csv
# Processed: 14.52% - 204.2.62.csv
# Saved: 205.1.66.csv - Lane column has only value 1, only specified columns saved.
# Saved: 206.1.64.csv - Lane column has only value 1, only specified columns saved.
# Processed: 14.86% - 207.1.63.csv
# Processed: 14.98% - 207.2.63.csv
# Saved: 209.1.65.csv - Lane column has only value 1, only specified columns saved.
# Processed: 15.21% - 210.1.62.csv
# Processed: 15.32% - 210.3.59.csv
# Processed: 15.44% - 211.1.275.csv
# Processed: 15.55% - 211.2.61.csv
# Processed: 15.67% - 211.3.61.csv
# Processed: 15.78% - 212.1.276.csv
# Processed: 15.90% - 212.2.364.csv
# Processed: 16.01% - 212.3.279.csv
# Processed: 16.13% - 212.4.363.csv
# Saved: 213.1.59.csv - Lane column has only value 1, only specified columns saved.
# Processed: 16.36% - 215.1.278.csv
# Processed: 16.47% - 215.2.362.csv
# Processed: 16.59% - 215.3.277.csv
# Processed: 16.71% - 215.4.366.csv
# Saved: 216.1.365.csv - Lane column has only value 1, only specified columns saved.
# Processed: 16.94% - 218.1.280.csv
# Processed: 17.05% - 218.2.360.csv
# Processed: 17.17% - 218.3.282.csv
# Processed: 17.28% - 218.4.173.csv
# Processed: 17.40% - 219.1.284.csv
# Processed: 17.51% - 219.2.282.csv
# Processed: 17.63% - 219.3.360.csv
# Processed: 17.74% - 219.4.361.csv
# Processed: 17.86% - 220.1.283.csv
# Processed: 17.97% - 220.2.286.csv
# Saved: 221.1.279.csv - Lane column has only value 1, only specified columns saved.
# Saved: 221.2.279.csv - Lane column has only value 1, only specified columns saved.
# Processed: 18.32% - 222.1.172.csv
# Processed: 18.43% - 222.2.285.csv
# Saved: 23.1.8.csv - Lane column has only value 1, only specified columns saved.
# Saved: 23.2.8.csv - Lane column has only value 1, only specified columns saved.
# Processed: 18.78% - 25.1.547.csv
# Processed: 18.89% - 25.2.97.csv
# Processed: 19.01% - 26.1.97.csv
# Processed: 19.12% - 26.2.98.csv
# Saved: 29.2.5.csv - Lane column has only value 1, only specified columns saved.
# Saved: 3.2.1.csv - Lane column has only value 1, only specified columns saved.
# Saved: 495.1.263.csv - Lane column has only value 1, only specified columns saved.
# Saved: 495.2.266.csv - Lane column has only value 1, only specified columns saved.
# Processed: 61.98% - 496.1.543.csv
# Processed: 62.10% - 496.2.266.csv
# Processed: 62.21% - 497.1.545.csv
# Processed: 62.33% - 499.2.542.csv
# Processed: 62.44% - 5.1.6.csv
# Saved: 5.739.460.csv - Lane column has only value 3, only specified columns saved.
# Processed: 62.67% - 50.2.12.csv
# Processed: 62.79% - 500.1.265.csv
# Processed: 62.90% - 502.1.269.csv
# Processed: 63.02% - 502.2.270.csv
# Processed: 63.13% - 503.1.271.csv
# Processed: 63.25% - 503.2.272.csv
# Processed: 63.36% - 504.1.273.csv
# Processed: 63.48% - 504.2.274.csv
# Processed: 63.59% - 505.1.274.csv
# Processed: 63.71% - 505.2.273.csv
# Processed: 63.82% - 506.1.272.csv
# Processed: 63.94% - 506.2.271.csv
# Processed: 64.06% - 507.1.270.csv
# Processed: 64.17% - 507.2.269.csv
# Saved: 512.1.125.csv - Lane column has only value 1, only specified columns saved.
# Saved: 513.1.106.csv - Lane column has only value 1, only specified columns saved.
# Saved: 514.1.140.csv - Lane column has only value 1, only specified columns saved.
# Saved: 515.1.152.csv - Lane column has only value 1, only specified columns saved.
# Saved: 515.2.154.csv - Lane column has only value 1, only specified columns saved.
# Saved: 516.1.151.csv - Lane column has only value 1, only specified columns saved.
# Saved: 516.2.149.csv - Lane column has only value 1, only specified columns saved.
# Saved: 516.3.141.csv - Lane column has only value 1, only specified columns saved.
# Saved: 517.3.9.csv - Lane column has only value 1, only specified columns saved.
# Saved: 518.2.94.csv - Lane column has only value 1, only specified columns saved.
# Saved: 519.1.145.csv - Lane column has only value 1, only specified columns saved.
# Saved: 519.2.144.csv - Lane column has only value 1, only specified columns saved.
# Saved: 520.1.79.csv - Lane column has only value 1, only specified columns saved.
# Saved: 520.2.155.csv - Lane column has only value 1, only specified columns saved.
# Saved: 520.3.153.csv - Lane column has only value 1, only specified columns saved.
# Saved: 521.1.156.csv - Lane column has only value 1, only specified columns saved.
# Processed: 66.13% - 522.1.17.csv
# Processed: 66.24% - 522.2.15.csv
# Processed: 66.36% - 523.1.12.csv
# Processed: 66.47% - 523.2.84.csv
# Processed: 66.59% - 524.3.8.csv
# Processed: 66.71% - 525.3.145.csv
# Processed: 66.82% - 526.1.144.csv
# Processed: 66.94% - 526.2.79.csv
# Processed: 67.05% - 527.3.141.csv
# Processed: 67.17% - 528.2.87.csv
# Processed: 67.28% - 529.1.81.csv
# Processed: 67.40% - 529.2.13.csv
# Processed: 67.51% - 529.3.14.csv
# Processed: 67.63% - 530.1.16.csv
# Saved: 531.1.12.csv - Lane column has only value 1, only specified columns saved.
# Saved: 536.1.100.csv - Lane column has only value 1, only specified columns saved.
# Saved: 537.1.100.csv - Lane column has only value 1, only specified columns saved.
# Saved: 54.1.14.csv - Lane column has only value 1, only specified columns saved.
# Saved: 54.2.14.csv - Lane column has only value 1, only specified columns saved.
# Saved: 540.1.100.csv - Lane column has only value 1, only specified columns saved.
# Saved: 541.1.100.csv - Lane column has only value 1, only specified columns saved.
# Saved: 546.1.406.csv - Lane column has only value 1, only specified columns saved.
# Saved: 547.1.400.csv - Lane column has only value 1, only specified columns saved.
# Saved: 548.1.376.csv - Lane column has only value 1, only specified columns saved.
# Saved: 548.2.401.csv - Lane column has only value 1, only specified columns saved.
# Processed: 69.01% - 55.1.13.csv
# Saved: 550.1.378.csv - Lane column has only value 1, only specified columns saved.
# Saved: 551.1.380.csv - Lane column has only value 1, only specified columns saved.
# Saved: 552.1.402.csv - Lane column has only value 1, only specified columns saved.
# Saved: 553.1.403.csv - Lane column has only value 1, only specified columns saved.
# Saved: 555.1.405.csv - Lane column has only value 1, only specified columns saved.
# Processed: 69.70% - 56.1.14.csv
# Saved: 568.1.104.csv - Lane column has only value 1, only specified columns saved.
# Processed: 69.93% - 57.1.13.csv
# Processed: 70.05% - 570.1.108.csv
# Saved: 572.1.391.csv - Lane column has only value 1, only specified columns saved.
# Saved: 574.1.394.csv - Lane column has only value 1, only specified columns saved.
# Processed: 70.39% - 575.1.537.csv
# Processed: 70.51% - 575.2.535.csv
# Processed: 70.62% - 575.3.540.csv
# Processed: 70.74% - 575.4.533.csv
# Processed: 70.85% - 575.5.446.csv
# Saved: 576.1.412.csv - Lane column has only value 1, only specified columns saved.
# Saved: 577.1.424.csv - Lane column has only value 1, only specified columns saved.
# Saved: 578.1.419.csv - Lane column has only value 1, only specified columns saved.
# Saved: 579.1.437.csv - Lane column has only value 1, only specified columns saved.
# Processed: 71.43% - 58.2.17.csv
# Saved: 580.1.436.csv - Lane column has only value 1, only specified columns saved.
# Processed: 71.66% - 581.1.444.csv
# Saved: 582.1.447.csv - Lane column has only value 1, only specified columns saved.
# Saved: 583.1.446.csv - Lane column has only value 1, only specified columns saved.
# Processed: 72.00% - 584.1.445.csv
# Saved: 585.1.432.csv - Lane column has only value 1, only specified columns saved.
# Saved: 586.1.434.csv - Lane column has only value 1, only specified columns saved.
# Saved: 587.1.427.csv - Lane column has only value 1, only specified columns saved.
# Saved: 588.1.422.csv - Lane column has only value 1, only specified columns saved.
# Saved: 589.1.410.csv - Lane column has only value 1, only specified columns saved.
# Processed: 72.70% - 59.1.18.csv
# Processed: 72.81% - 59.2.18.csv
# Processed: 72.93% - 591.1.464.csv
# Processed: 73.04% - 591.2.466.csv
# Processed: 73.16% - 592.1.468.csv
# Processed: 73.27% - 592.2.470.csv
# Processed: 73.39% - 593.1.472.csv
# Processed: 73.50% - 593.2.474.csv
# Processed: 73.62% - 594.1.476.csv
# Processed: 73.73% - 594.2.478.csv
# Processed: 73.85% - 595.1.481.csv
# Processed: 73.96% - 595.2.482.csv
# Processed: 74.08% - 596.1.485.csv
# Processed: 74.19% - 596.2.487.csv
# Processed: 74.31% - 597.1.488.csv
# Processed: 74.42% - 597.2.490.csv
# Processed: 74.54% - 598.1.492.csv
# Processed: 74.65% - 599.1.495.csv
# Processed: 74.77% - 599.2.497.csv
# Processed: 74.88% - 6.2.264.csv
# Processed: 75.00% - 600.1.500.csv
# Processed: 75.12% - 600.2.502.csv
# Processed: 75.23% - 601.1.503.csv
# Processed: 75.35% - 602.2.504.csv
# Processed: 75.46% - 603.1.501.csv
# Processed: 75.58% - 604.1.498.csv
# Processed: 75.69% - 604.2.496.csv
# Processed: 75.81% - 605.1.494.csv
# Processed: 75.92% - 605.2.493.csv
# Processed: 76.04% - 606.1.491.csv
# Processed: 76.15% - 606.2.489.csv
# Processed: 76.27% - 607.2.484.csv
# Processed: 76.38% - 608.1.483.csv
# Processed: 76.50% - 608.2.480.csv
# Processed: 76.61% - 609.1.479.csv
# Processed: 76.73% - 609.2.477.csv
# Saved: 61.1.18.csv - Lane column has only value 1, only specified columns saved.
# Saved: 61.2.18.csv - Lane column has only value 1, only specified columns saved.
# Saved: 61.3.18.csv - Lane column has only value 1, only specified columns saved.
# Processed: 77.19% - 610.1.475.csv
# Processed: 77.30% - 610.2.473.csv
# Processed: 77.42% - 611.1.471.csv
# Processed: 77.53% - 611.2.469.csv
# Processed: 77.65% - 612.1.467.csv
# Processed: 77.76% - 612.2.465.csv
# Saved: 615.1.465.csv - Lane column has only value 1, only specified columns saved.
# Saved: 616.1.467.csv - Lane column has only value 1, only specified columns saved.
# Saved: 617.1.469.csv - Lane column has only value 1, only specified columns saved.
# Saved: 618.1.471.csv - Lane column has only value 1, only specified columns saved.
# Saved: 619.1.473.csv - Lane column has only value 1, only specified columns saved.
# Saved: 620.1.475.csv - Lane column has only value 1, only specified columns saved.
# Saved: 621.1.477.csv - Lane column has only value 1, only specified columns saved.
# Saved: 622.1.479.csv - Lane column has only value 1, only specified columns saved.
# Saved: 623.1.480.csv - Lane column has only value 1, only specified columns saved.
# Saved: 624.1.483.csv - Lane column has only value 1, only specified columns saved.
# Saved: 625.1.484.csv - Lane column has only value 1, only specified columns saved.
# Saved: 627.1.489.csv - Lane column has only value 1, only specified columns saved.
# Saved: 628.1.491.csv - Lane column has only value 1, only specified columns saved.
# Processed: 79.38% - 629.1.493.csv
# Processed: 79.49% - 63.2.18.csv
# Processed: 79.61% - 630.1.494.csv
# Processed: 79.72% - 631.1.496.csv
# Saved: 632.1.498.csv - Lane column has only value 1, only specified columns saved.
# Processed: 79.95% - 634.1.501.csv
# Processed: 80.07% - 635.1.504.csv
# Saved: 636.1.464.csv - Lane column has only value 1, only specified columns saved.
# Saved: 638.1.468.csv - Lane column has only value 1, only specified columns saved.
# Saved: 639.1.466.csv - Lane column has only value 1, only specified columns saved.
# Processed: 80.53% - 64.1.19.csv
# Saved: 640.1.472.csv - Lane column has only value 1, only specified columns saved.
# Saved: 641.1.470.csv - Lane column has only value 1, only specified columns saved.
# Saved: 642.1.476.csv - Lane column has only value 1, only specified columns saved.
# Saved: 643.1.474.csv - Lane column has only value 1, only specified columns saved.
# Saved: 644.1.481.csv - Lane column has only value 1, only specified columns saved.
# Saved: 645.1.478.csv - Lane column has only value 1, only specified columns saved.
# Saved: 646.1.485.csv - Lane column has only value 1, only specified columns saved.
# Saved: 647.1.482.csv - Lane column has only value 1, only specified columns saved.
# Saved: 648.1.488.csv - Lane column has only value 1, only specified columns saved.
# Saved: 649.1.487.csv - Lane column has only value 1, only specified columns saved.
# Saved: 65.1.19.csv - Lane column has only value 1, only specified columns saved.
# Saved: 65.2.19.csv - Lane column has only value 1, only specified columns saved.
# Saved: 650.1.492.csv - Lane column has only value 1, only specified columns saved.
# Saved: 651.1.490.csv - Lane column has only value 1, only specified columns saved.
# Saved: 652.1.495.csv - Lane column has only value 1, only specified columns saved.
# Processed: 82.37% - 653.1.492.csv
# Saved: 654.1.500.csv - Lane column has only value 1, only specified columns saved.
# Processed: 82.60% - 655.1.497.csv
# Processed: 82.72% - 656.1.503.csv
# Processed: 82.83% - 657.1.502.csv
# Processed: 82.95% - 658.2.549.csv
# Processed: 83.06% - 659.1.550.csv
# Processed: 83.18% - 659.2.551.csv
# Processed: 83.29% - 660.1.552.csv
# Processed: 83.41% - 664.1.461.csv
# Processed: 83.53% - 664.2.449.csv
# Processed: 83.64% - 665.1.25.csv
# Processed: 83.76% - 665.2.462.csv
# Processed: 83.87% - 665.3.453.csv
# Processed: 83.99% - 666.1.455.csv
# Processed: 84.10% - 666.2.457.csv
# Processed: 84.22% - 666.3.459.csv
# Processed: 84.33% - 667.1.556.csv
# Processed: 84.45% - 668.1.554.csv
# Processed: 84.56% - 668.2.555.csv
# Processed: 84.68% - 669.2.553.csv
# Processed: 84.79% - 673.1.451.csv
# Processed: 84.91% - 673.2.460.csv
# Processed: 85.02% - 674.1.454.csv
# Processed: 85.14% - 674.2.463.csv
# Processed: 85.25% - 675.1.458.csv
# Processed: 85.37% - 675.2.456.csv
# Processed: 85.48% - 675.3.452.csv
# Saved: 676.1.25.csv - Lane column has only value 1, only specified columns saved.
# Saved: 677.1.449.csv - Lane column has only value 1, only specified columns saved.
# Saved: 678.1.455.csv - Lane column has only value 1, only specified columns saved.
# Saved: 679.1.453.csv - Lane column has only value 1, only specified columns saved.
# Saved: 681.1.459.csv - Lane column has only value 1, only specified columns saved.
# Saved: 682.1.451.csv - Lane column has only value 1, only specified columns saved.
# Saved: 684.1.454.csv - Lane column has only value 1, only specified columns saved.
# Saved: 685.1.452.csv - Lane column has only value 1, only specified columns saved.
# Saved: 686.1.458.csv - Lane column has only value 1, only specified columns saved.
# Processed: 86.64% - 688.2.519.csv
# Processed: 86.75% - 689.1.522.csv
# Processed: 86.87% - 689.2.521.csv
# Processed: 86.98% - 689.3.520.csv
# Processed: 87.10% - 69.1.52.csv
# Processed: 87.21% - 69.2.16.csv
# Processed: 87.33% - 69.3.776.csv
# Processed: 87.44% - 690.1.524.csv
# Processed: 87.56% - 690.2.523.csv
# Processed: 87.67% - 691.2.525.csv
# Processed: 87.79% - 692.1.516.csv
# Processed: 87.90% - 693.1.538.csv
# Saved: 694.1.538.csv - Lane column has only value 1, only specified columns saved.
# Saved: 695.1.536.csv - Lane column has only value 1, only specified columns saved.
# Saved: 697.1.537.csv - Lane column has only value 1, only specified columns saved.
# Processed: 88.36% - 7.1.264.csv
# Processed: 88.48% - 70.1.775.csv
# Processed: 88.59% - 70.2.21.csv
# Processed: 88.71% - 702.1.721.csv
# Processed: 88.82% - 702.2.721.csv
# Processed: 88.94% - 702.2.723.csv
# Processed: 89.06% - 702.3.723.csv
# Processed: 89.17% - 702.3.724.csv
# Processed: 89.29% - 702.3.726.csv
# Saved: 703.1.725.csv - Lane column has only value 2, only specified columns saved.
# Processed: 89.52% - 703.1.726.csv
# Processed: 89.63% - 704.1.727.csv
# Processed: 89.75% - 705.1.728.csv
# Processed: 89.86% - 705.2.729.csv
# Processed: 89.98% - 705.3.730.csv
# Processed: 90.09% - 705.4.731.csv
# Processed: 90.21% - 706.1.732.csv
# Processed: 90.32% - 706.2.733.csv
# Processed: 90.44% - 706.3.734.csv
# Processed: 90.55% - 706.4.735.csv
# Processed: 90.67% - 706.5.736.csv
# Processed: 90.78% - 707.1.737.csv
# Processed: 90.90% - 707.2.738.csv
# Processed: 91.01% - 707.3.739.csv
# Processed: 91.13% - 707.4.740.csv
# Processed: 91.24% - 71.2.23.csv
# Processed: 91.36% - 710.2.740.csv
# Processed: 91.47% - 710.3.739.csv
# Processed: 91.59% - 710.4.738.csv
# Processed: 91.71% - 710.5.737.csv
# Processed: 91.82% - 711.1.736.csv
# Processed: 91.94% - 711.2.735.csv
# Processed: 92.05% - 711.3.734.csv
# Processed: 92.17% - 711.4.733.csv
# Processed: 92.28% - 711.5.732.csv
# Processed: 92.40% - 712.1.731.csv
# Processed: 92.51% - 712.2.730.csv
# Processed: 92.63% - 712.3.729.csv
# Processed: 92.74% - 712.4.728.csv
# Processed: 92.86% - 713.2.727.csv
# Processed: 92.97% - 714.2.725.csv
# Processed: 93.09% - 714.2.726.csv
# Processed: 93.20% - 715.1.724.csv
# Processed: 93.32% - 715.1.725.csv
# Processed: 93.43% - 715.1.748.csv
# Processed: 93.55% - 715.2.722.csv
# Processed: 93.66% - 715.2.724.csv
# Processed: 93.78% - 715.3.722.csv
# Saved: 716.1.729.csv - Lane column has only value 1, only specified columns saved.
# Saved: 717.2.727.csv - Lane column has only value 1, only specified columns saved.
# Saved: 718.2.727.csv - Lane column has only value 1, only specified columns saved.
# Saved: 719.1.729.csv - Lane column has only value 1, only specified columns saved.
# Processed: 94.35% - 72.1.22.csv
# Processed: 94.47% - 72.2.28.csv
# Saved: 720.2.725.csv - Lane column has only value 1, only specified columns saved.
# Processed: 94.70% - 727.1.741.csv
# Processed: 94.82% - 728.2.742.csv
# Saved: 73.2.23.csv - Lane column has only value 1, only specified columns saved.
# Processed: 95.05% - 730.1.745.csv
# Processed: 95.16% - 731.2.744.csv
# Processed: 95.28% - 732.2.728.csv
# Processed: 95.39% - 733.1.747.csv
# Processed: 95.51% - 733.1.749.csv
# Processed: 95.62% - 733.2.747.csv
# Processed: 95.74% - 734.1.746.csv
# Processed: 95.85% - 734.2.723.csv
# Saved: 737.2.744.csv - Lane column has only value 1, only specified columns saved.
# Saved: 738.1.745.csv - Lane column has only value 1, only specified columns saved.
# Processed: 96.20% - 74.1.22.csv
# Saved: 740.1.549.csv - Lane column has only value 1, only specified columns saved.
# Saved: 741.2.550.csv - Lane column has only value 1, only specified columns saved.
# Saved: 743.2.552.csv - Lane column has only value 1, only specified columns saved.
# Saved: 744.1.553.csv - Lane column has only value 1, only specified columns saved.
# Saved: 745.2.554.csv - Lane column has only value 1, only specified columns saved.
# Saved: 746.1.555.csv - Lane column has only value 1, only specified columns saved.
# Saved: 747.2.556.csv - Lane column has only value 1, only specified columns saved.
# Processed: 97.12% - 748.1.777.csv
# Processed: 97.24% - 749.1.201.csv
# Processed: 97.35% - 76.2.26.csv
# Processed: 97.47% - 77.2.24.csv
# Processed: 97.58% - 78.1.773.csv
# Processed: 97.70% - 78.2.20.csv
# Processed: 97.81% - 8.1.7.csv
# Processed: 97.93% - 8.2.5.csv
# Saved: 80.2.24.csv - Lane column has only value 1, only specified columns saved.
# Processed: 98.16% - 81.2.24.csv
# Saved: 86.1.28.csv - Lane column has only value 2, only specified columns saved.
# Saved: 88.1.28.csv - Lane column has only value 1, only specified columns saved.
# Processed: 98.50% - 89.1.28.csv
# Processed: 98.62% - 89.2.30.csv
# Processed: 98.73% - 9.1.3.csv
# Processed: 98.85% - 90.2.30.csv
# Processed: 98.96% - 91.1.31.csv
# Processed: 99.08% - 91.2.29.csv
# Processed: 99.19% - 92.2.27.csv
# Processed: 99.31% - 95.1.29.csv
# Processed: 99.42% - 97.1.33.csv
# Processed: 99.54% - 97.2.33.csv
# Processed: 99.65% - 97.3.38.csv
# Processed: 99.77% - 98.2.34.csv
# Processed: 99.88% - 98.3.32.csv
# Processed: 100.00% - 99.1.35.csv
# Total files saved at destination folder: 868

# %%
# check if all the files are present in the destination folder
import os

def find_missing_files(source_folder, destination_folder):
    # Get list of files in source folder
    source_files = set(os.listdir(source_folder))

    # Get list of files in destination folder
    destination_files = set(os.listdir(destination_folder))

    # Find missing files
    missing_files = source_files - destination_files

    return missing_files

# Example usage:
source_folder = 'E:/xie/Sensor Files/1. raw data - separated sensor files - num checked out with the db/2019'
destination_folder = 'E:/xie/Sensor Files/2. transformed - aggregated sensor files/2019'

missing_files = find_missing_files(source_folder, destination_folder)

if missing_files:
    print("Files missing at destination folder:")
    for file in missing_files:
        print(file)
else:
    print("All files are present in the destination folder.")
# Out:
# All files are present in the destination folder.

# %% [markdown]
# # data imputation routine::

# %%
#CSV File Filtering based on Row Count

import os
import shutil
import pandas as pd

source_directory = "D:/xie_sepa/agg/2019"
destination_directory = "D:/xie_sepa/agg/2019-70-percent"
threshold_row_count = 0.7 * 35040  # 70% of 35040 rows

# Ensure destination directory exists or create it
if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

for filename in os.listdir(source_directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(source_directory, filename)
        data = pd.read_csv(filepath)
        row_count = len(data)
        if row_count >= threshold_row_count:
            shutil.copy(filepath, destination_directory)

# %%
import os
import pandas as pd
from datetime import datetime, timedelta

# Function to normalize time to the nearest 15-minute increment
def round_time_to_15min(dt):
    dt += timedelta(minutes=7.5)
    dt -= timedelta(minutes=dt.minute % 15, seconds=dt.second)
    return dt

# Function to fill gaps in the data with -1
def fill_gaps(df):
    start_time = df['DateTimeStamp'].min()
    end_time = df['DateTimeStamp'].max()
    expected_times = pd.date_range(start=start_time, end=end_time, freq='15T')
    missing_times = expected_times[~expected_times.isin(df['DateTimeStamp'])]

    missing_data = pd.DataFrame({
        'DateTimeStamp': missing_times,
        'Occupancy': -1,
        'Volume': -1,
        'Speed': -1
    })

    df = pd.concat([df, missing_data]).sort_values(by='DateTimeStamp').reset_index(drop=True)
    return df

# Directory containing CSV files
input_directory = 'C:/Users/Tarek Zahid/Desktop/xie/2018'
output_directory = 'C:/Users/Tarek Zahid/Desktop/xie/2018_processed'

# Read and process each CSV file
for filename in os.listdir(input_directory):
    if filename.endswith(".csv"):
        input_filepath = os.path.join(input_directory, filename)
        df = pd.read_csv(input_filepath, parse_dates=['DateTimeStamp'])

        # Normalize time to the nearest 15-minute increment
        df['DateTimeStamp'] = df['DateTimeStamp'].apply(round_time_to_15min)

        # Fill gaps in the data with -1
        df = fill_gaps(df)

        # Save the processed data to a new CSV file
        output_filename = os.path.splitext(filename)[0] + '_processed.csv'
        output_filepath = os.path.join(output_directory, output_filename)
        df.to_csv(output_filepath, index=False)

        print(f"Processed file: {output_filepath}")

# %%
import os
import pandas as pd
from tqdm import tqdm
from fancyimpute import IterativeImputer

# Input and output directories (adjust paths as needed)
input_directory = 'C:/Users/Tarek Zahid/Desktop/xie/2018_processed'
output_directory = 'C:/Users/Tarek Zahid/Desktop/xie/2018_processed_imputed'

# Function to replace -1 values with NaN
def replace_missing_values(df):
    return df.replace(-1, float('NaN'))

# Function to perform imputation on individual columns
def perform_imputation(df):
    imputer = IterativeImputer()
    imputed_data = imputer.fit_transform(df)
    return imputed_data

# Iterate through processed files
for filename in os.listdir(input_directory):
    if filename.endswith("_processed.csv"):
        input_filepath = os.path.join(input_directory, filename)
        output_filepath = os.path.join(output_directory, filename)

        # Read the processed file
        df = pd.read_csv(input_filepath)

        # Drop the first column (DateTime)
        df = df.drop(columns=df.columns[0])

        # Replace -1 values with NaN
        df = replace_missing_values(df)

        # Check if there are columns for imputation
        if len(df.columns) >= 3:
            # Perform imputation for each remaining column
            imputed_data = perform_imputation(df)

            # Convert back to DataFrame
            imputed_df = pd.DataFrame(imputed_data, columns=df.columns)

            # Add the DateTime column back
            datetime_column = pd.read_csv(input_filepath, usecols=[0])  # Read DateTime column
            imputed_df = pd.concat([datetime_column, imputed_df], axis=1)  # Concatenate with imputed data

            # Save the imputed DataFrame to CSV
            imputed_df.to_csv(output_filepath, index=False)

            print(f"Imputed and saved file: {output_filepath}")
        else:
            print(f"Skipping file {filename} as it does not contain enough columns for imputation.")

# %%
# Chloe's cleaned sensor list
sen_list_path = 'C:/Users/Tarek Zahid/Desktop/xie/Chloe - Reduced Detector Data - all_combined.csv'
sen_list = pd.read_csv(sen_list_path)
sen_list.head(20)

# Filter Condition: region and ignore
region = 'I-15 NB'
ignore = 'Ramp'
ignore_lat_lon = [(36.299400, -115.286400)]

filtered_sen_list = sen_list[sen_list['Location'].str.contains(region) & ~sen_list['Location'].str.contains(ignore)]
filtered_sen_list['Latitude'] = filtered_sen_list['Latitude'].astype(str).apply(lambda x: x[:2] + '.' + x[2:])
filtered_sen_list['Longitude'] = filtered_sen_list['Longitude'].astype(str).apply(lambda x: x[:4] + '.' + x[4:])

filtered_sen_list = filtered_sen_list[~filtered_sen_list.apply(lambda row: (row['Latitude'], row['Longitude']) in ignore_lat_lon, axis=1)]
filtered_sen_list = filtered_sen_list.sort_values(by="Latitude")


filtered_sen_list.head(20)
len(filtered_sen_list)
# Out:
# C:\Users\Tarek Zahid\AppData\Local\Temp\ipykernel_5288\3926870401.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_sen_list['Latitude'] = filtered_sen_list['Latitude'].astype(str).apply(lambda x: x[:2] + '.' + x[2:])
# C:\Users\Tarek Zahid\AppData\Local\Temp\ipykernel_5288\3926870401.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_sen_list['Longitude'] = filtered_sen_list['Longitude'].astype(str).apply(lambda x: x[:4] + '.' + x[4:])
# 135

# %%
import folium
latitude = pd.to_numeric(filtered_sen_list['Latitude'])
longitude = pd.to_numeric(filtered_sen_list['Longitude'])

# Create a map centered at the mean latitude and longitude, with zoom level 10
map = folium.Map(location=[latitude.mean(), longitude.mean()], zoom_start=10)

# Add a blue circle for each location, with a tooltip showing the latitude, longitude, and text from column 2
for lat, lon, text in zip(latitude, longitude, location):
    tooltip_text = f"Latitude: {lat}, Longitude: {lon}, Text: {text}"
    folium.Circle(location=[lat, lon], radius=20, color='blue', fill=True, fill_color='blue',
                  tooltip=tooltip_text).add_to(map)

# Display the map 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be1c4ab8c7ae1a3e74d086c911374143 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be1c4ab8c7ae1a3e74d086c911374143&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be1c4ab8c7ae1a3e74d086c911374143 = L.map(
#                 &quot;map_be1c4ab8c7ae1a3e74d086c911374143&quot;,
#                 {
#                     center: [36.03189164214816, -115.1881757711111],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_764ede7b20b8494eb8047a9af9a643c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_764ede7b20b8494eb8047a9af9a643c8.addTo(map_be1c4ab8c7ae1a3e74d086c911374143);
#
#
#             var circle_347ee4844684650c1c1a41427b3f1bc4 = L.circle(
#                 [35.6096866, -115.3900209],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_be1c4ab8c7ae1a3e74d086c911374143);
#
#
#             circle_347ee4844684650c1c1a41427b3f1bc4.bindTooltip(
#                 `&lt;div&gt;
#                      Latitude: 35.6096866, Longitude: -115.3900209, Text: I-215 WB/I-15 NB between CC-215 WB and I-15 NB
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_d04ead260a328d5107563b0c6c5bde42 = L.circle(
#                 [35.61556389, -115.3877],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_be1c4ab8c7ae1a3e74d086c911374143);
#
#
#             circle_d04ead260a328d5107563b0c6c5bde42.bindTooltip(
#                 `&lt;div&gt;
#                      Latitude: 35.61556389, Longitude: -115.3877, Text: I-215 WB/I-15 NB between CC-215 WB and I-15 NB
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_6185c80106ed168cd1a174aa046d7564 = L.circle(
#                 [35.62113534, -115.3865751],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_be1c4ab8c7ae1a3e74d086c911374143);
#
#
#             circle_6185c80106ed168cd1a174aa046d7564.bindTooltip(
#                 `&lt;div&gt;
#                      Latitude: 35.62113534, Longitude: -115.3865751, Text: I-15 NB between Alexander Road and Craig Road
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_f0ef662c40b9f18951ac2d59fe87826a = L.circle(
#                 [35.631138, -115.38485],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_be1c4ab8c7ae1a3e74d086c911374143);
#
#
#             circle_f0ef662c40b9f18951ac2d59fe87826a.bindTooltip(
#                 `&lt;div&gt;
#                      Latitude: 35.631138, Longitude: -115.38485, Text: I-15 NB between Craig Road and Smiley Road
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_fdf425ce70fb3f5298a39e7e17a511f9 = L.circle(
#                 [35.64038301, -115.3833446],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&

# %%
detector_ids = filtered_sen_list['DetectorID'].str.replace('_', '.').tolist()
print(detector_ids)
# Out:
# ['451.1.99', '450.1.99', '450.2.359', '449.1.358', '449.2.357', '449.3.356', '448.1.355', '448.2.354', '448.3.353', '447.1.352', '447.2.351', '447.3.77', '446.1.350', '446.2.78', '446.3.349', '445.1.348', '445.2.347', '445.3.346', '444.1.100', '444.3.345', '443.1.344', '443.2.343', '443.3.342', '442.1.341', '442.2.340', '442.3.339', '441.1.338', '441.2.337', '444.2.100', '441.3.336', '440.1.335', '439.1.334', '439.2.333', '439.3.332', '438.1.331', '438.2.330', '438.3.329', '437.1.101', '437.1.328', '437.2.328', '437.2.327', '437.3.327', '359.1.325', '358.1.325', '358.2.320', '358.3.319', '357.1.312', '357.2.311', '357.3.310', '356.1.309', '356.2.308', '356.3.313', '355.1.156', '355.2.153', '355.3.155', '354.1.79', '526.2.79', '354.2.144', '526.1.144', '354.3.145', '525.3.145', '525.2.142', '32.1.142', '525.1.93', '34.1.94', '34.2.90', '524.3.90', '524.3.8', '23.1.8', '39.2.88', '23.2.8', '524.1.8', '48.2.83', '524.1.85', '523.2.84', '49.1.82', '49.2.12', '523.1.12', '522.2.15', '49.3.15', '522.1.17', '58.2.17', '59.1.18', '59.2.18', '70.2.21', '71.2.23', '72.1.22', '72.2.28', '89.1.28', '89.2.30', '97.1.33', '97.2.33', '97.3.38', '99.1.35', '110.1.41', '112.2.44', '113.2.45', '122.2.48', '124.2.49', '137.1.80', '138.1.53', '146.2.238', '148.2.58', '149.2.240', '161.2.241', '160.1.241 ', '160.2.242', '396.1.243', '396.2.246', '396.3.246', '397.1.247', '398.1.249', '398.2.251', '398.3.411', '399.1.413', '399.2.414', '399.3.417', '399.4.418', '400.1.423', '400.2.425', '400.3.430', '400.4.431', '401.1.435', '401.2.437', '402.1.438', '402.2.439', '402.3.443', '402.4.444', '403.1.447', '693.1.538', '403.2.533', '403.3.448', '403.3.534', '403.4.535', '403.5.536']

# %%
import os
import shutil

# Assuming you have a list of detector IDs from the filtered_sen_list DataFrame
detector_ids = filtered_sen_list['DetectorID'].str.replace('_', '.').tolist()

# List of directories
directories = ['C:/Users/Tarek Zahid/Desktop/xie/2018_processed', 'C:/Users/Tarek Zahid/Desktop/xie/2019_processed']

# Create the output folders if they don't exist
output_folder1 = 'C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/2018'  
output_folder2 = 'C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/2019'  
if not os.path.exists(output_folder1):
    os.makedirs(output_folder1)
if not os.path.exists(output_folder2):
    os.makedirs(output_folder2)

# Create dictionaries to store the count of files for each directory
file_counts1 = {}
file_counts2 = {}

# Iterate over each directory
for i, directory in enumerate(directories):
    # Determine the output folder based on the directory index
    output_folder = output_folder1 if i == 0 else output_folder2
    file_counts = file_counts1 if i == 0 else file_counts2
    file_counts[directory] = 0
    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Remove '_processed.csv' from the filename
        detector_name = filename.replace('_processed.csv', '')
        # Check if the detector name matches any detector ID in the list
        for detector_id in detector_ids:
            if detector_id in detector_name:
                # Construct source and destination paths
                source_path = os.path.join(directory, filename)
                destination_path = os.path.join(output_folder, filename)
                # Copy the file to the output folder
                shutil.copyfile(source_path, destination_path)
                print(f"Copied '{filename}' from '{directory}' to '{output_folder}'.")
                file_counts[directory] += 1  # Increment the file count for the directory
                break  # Stop searching for detector IDs once a match is found

# Print the file counts for each directory
for directory, count in file_counts1.items():
    print(f"Directory '{directory}' has {count} files matching the detector IDs.")
for directory, count in file_counts2.items():
    print(f"Directory '{directory}' has {count} files matching the detector IDs.")

# %%
import os
import pandas as pd

directories = ['C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/2018', 'C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/2019' ]

# Dictionary to store the file counts and min/max rows for each directory
file_info = {}

# Iterate over each directory
for directory in directories:
    # List to store the number of rows for each CSV file in the directory
    row_counts = []
    # Iterate over files in the directory
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            # Read the CSV file
            file_path = os.path.join(directory, filename)
            df = pd.read_csv(file_path)
            # Count the number of rows in the DataFrame
            num_rows = len(df)
            row_counts.append(num_rows)
    # Store the file count and min/max row counts for the directory
    file_info[directory] = {
        "file_count": len(row_counts),
        "min_rows": min(row_counts),
        "max_rows": max(row_counts)
    }

# Print the file counts and min/max row counts for each directory
for directory, info in file_info.items():
    print(f"Directory '{directory}' has {info['file_count']} CSV files.")
    print(f"Minimum number of rows: {info['min_rows']}")
    print(f"Maximum number of rows: {info['max_rows']}")
# Out:
# Directory 'C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/2018' has 107 CSV files.
# Minimum number of rows: 6959
# Maximum number of rows: 35042
# Directory 'C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/2019' has 107 CSV files.
# Minimum number of rows: 2520
# Maximum number of rows: 35045

# %%
import pandas as pd
import os

# Define the directories
directories = ['C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/2018', 'C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/2019' ]
# Function to read CSV files and extract the 'Speed' column
def read_speed_data(directory):
    speed_data = pd.DataFrame()  # Initialize an empty DataFrame
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if filepath.endswith('.csv'):
            df = pd.read_csv(filepath, usecols=['DateTimeStamp', 'Speed'])  # Read only 'DateTimeStamp' and 'Speed' columns
            speed_data[filename] = df['Speed']  # Add 'Speed' column to the DataFrame with the filename as column name
    return speed_data

# Read speed data for each directory
speed_data_2018 = read_speed_data(directories[0])
speed_data_2019 = read_speed_data(directories[1])

# Merge datasets based on 'DateTimeStamp'
merged_data_2018.to_csv('C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/datasets/merged_data_2018.csv', index=False)
merged_data_2019.to_csv('C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/datasets/merged_data_2019.csv', index=False)

# Replace 0 speed values with -1
merged_data_2018.replace(0, -1, inplace=True)
merged_data_2019.replace(0, -1, inplace=True)

# Save the merged datasets to CSV files
merged_data_2018.to_csv('merged_data_2018.csv', index=False)
merged_data_2019.to_csv('merged_data_2019.csv', index=False)

# Display the shape of each merged dataset
print(f"Merged data for 2018 has {merged_data_2018.shape[0]} rows and {merged_data_2018.shape[1]} columns.")
print(f"Merged data for 2019 has {merged_data_2019.shape[0]} rows and {merged_data_2019.shape[1]} columns.")

# %%
import pandas as pd
import os

# Define the directories
directories = ['C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/2018', 'C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/2019']

# Function to read CSV files and extract the 'Speed' and 'DateTimeStamp' columns
def read_speed_data(directory):
    speed_data = pd.DataFrame()  # Initialize an empty DataFrame
    datetime_column = pd.DataFrame()  # Initialize an empty DataFrame for DateTimeStamp
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if filepath.endswith('.csv'):
            df = pd.read_csv(filepath)  # Read the entire CSV file
            speed_data[filename] = df['Speed']  # Add 'Speed' column to the DataFrame with the filename as column name
            datetime_column[filename] = df['DateTimeStamp']  # Add 'DateTimeStamp' column to the DataFrame with the filename as column name
    return speed_data, datetime_column

# Read speed and datetime data for each directory
speed_data_2018, datetime_2018 = read_speed_data(directories[0])
speed_data_2019, datetime_2019 = read_speed_data(directories[1])

# Merge datasets based on 'DateTimeStamp'
merged_data_2018 = pd.concat([datetime_2018, speed_data_2018], axis=1)
merged_data_2019 = pd.concat([datetime_2019, speed_data_2019], axis=1)

# Replace NaN values with -1
merged_data_2018.fillna(-1, inplace=True)
merged_data_2019.fillna(-1, inplace=True)

# Save the merged datasets to CSV files
merged_data_2018.to_csv('C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/datasets/merged_data_2018.csv', index=False)
merged_data_2019.to_csv('C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/datasets/merged_data_2019.csv', index=False)

# Save original 'DateTimeStamp' column as separate files
datetime_2018.to_csv('C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/datasets/datetime_2018.csv', index=False)
datetime_2019.to_csv('C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/datasets/datetime_2019.csv', index=False)

# Display the shape of each merged dataset
print(f"Merged data for 2018 has {merged_data_2018.shape[0]} rows and {merged_data_2018.shape[1]} columns.")
print(f"Merged data for 2019 has {merged_data_2019.shape[0]} rows and {merged_data_2019.shape[1]} columns.")

# %%
import pandas as pd
import os

# Step 1: Read all CSV files from the directory
directory = 'C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/2018'
all_files = os.listdir(directory)
csv_files = [file for file in all_files if file.endswith('.csv')]

# Initialize DataFrame to store concatenated speeds
concatenated_speeds = pd.DataFrame()

# Step 2-4: Extract and merge DateTimeStamp and Speed columns
for file in csv_files:
    df = pd.read_csv(os.path.join(directory, file))
    if 'DateTimeStamp' in df.columns and 'Speed' in df.columns:
        df = df[['DateTimeStamp', 'Speed']]
        if concatenated_speeds.empty:
            concatenated_speeds = df
        else:
            # Specify suffixes for the columns to avoid duplicate column names
            concatenated_speeds = pd.merge(concatenated_speeds, df, on='DateTimeStamp', how='inner', suffixes=('', '_'+file.split('.')[0]))

# Step 5: Save the Speed file and the common DateTimeStamp file
concatenated_speeds.to_csv(os.path.join(directory, 'C:/Users/Tarek Zahid/Desktop/xie/dataset-common sensor 18-19-(-1)-imputated/I-15 NB/datasets/concatenated_speeds.csv'), index=False)

# Save the common DateTimeStamp file
common_date_time = concatenated_speeds['DateTimeStamp']
common_date_time.to_csv(os.path.join(directory, 'common_date_time.csv'), index=False)

# Step 6: Count the number of common rows
num_common_rows = len(concatenated_speeds)
print("Number of common rows:", num_common_rows)
# Out:
# Number of common rows: 493

# %%
import csv
import os

def check_csv_columns(directory):
    # List to store files with less than 4 columns
    incorrect_files = []

    # Iterate through all files in the directory
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):  # Check if file is a CSV file
            file_path = os.path.join(directory, filename)
            with open(file_path, 'r', newline='') as csvfile:
                reader = csv.reader(csvfile)
                # Check number of columns in each row
                for row in reader:
                    if len(row) != 4:
                        incorrect_files.append(filename)
                        break  # No need to check further rows if columns are incorrect
    return incorrect_files

# Example usage:
directory_path = "C:/Users/Tarek Zahid/Desktop/xie/2018"
incorrect_files_list = check_csv_columns(directory_path)

if incorrect_files_list:
    print("Files with less than 4 columns:")
    for file in incorrect_files_list:
        print(file)
else:
    print("All CSV files have 4 column")
# Out:
# Files with less than 4 columns:
# 139.2.53.csv
# 213.1.59.csv
# 5.739.460.csv
# 536.1.100.csv
# 707.3.739.csv
